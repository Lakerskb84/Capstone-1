# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('fishing_results.csv')
print (df)
# Out:
#        Year         Survey  Station  Latitude  Longitude  \
# 0      2017  United States        1    58.778   -177.575
# 1      2017  United States        1    58.778   -177.575
# 2      2017  United States        1    58.778   -177.575
# 3      2017  United States        1    58.778   -177.575
# 4      2017  United States        1    58.778   -177.575
# 5      2017  United States        1    58.778   -177.575
# 6      2017  United States        1    58.778   -177.575
# 7      2017  United States        2    58.620   -176.642
# 8      2017  United States        2    58.620   -176.642
# 9      2017  United States        2    58.620   -176.642
# 10     2017  United States        2    58.620   -176.642
# 11     2017  United States        2    58.620   -176.642
# 12     2017  United States        2    58.620   -176.642
# 13     2017  United States        2    58.620   -176.642
# 14     2017  United States        4    58.497   -175.670
# ...

# %%
#printing Dataset using excel and slicing year mean weight data
rows=df.iloc['year', 'mean weight']
plt.plot(rows)
plt.title('this is a test')
plt.xlabel('amount')
plt.ylabel('total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a61cf5449889> in <module>()
#       1 #printing Dataset using excel rows 100 through 120
# ----> 2 rows=df.iloc['year', 'mean weight']
#       3 plt.plot(rows)
#       4 plt.title('this is a test')
#       5 plt.xlabel('amount')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# ...
