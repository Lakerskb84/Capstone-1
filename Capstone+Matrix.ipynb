# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyexcel_ods3 import get_data

# %%
data= 'seadata.csv'
df=pd.read_csv(data)
print(df)
# Out:
#        #--------------------------------------------------------------------------------  \
# 0                            CAST
# 1                            NODC Cruise ID
# 2                            Originators Station ID
# 3                            Originators Cruise ID
# 4                            Latitude
# 5                            Longitude
# 6                            Year
# 7                            Month
# 8                            Day
# 9                                                METADATA
# 10                           Country
# 11                           Accession Number
# 12                           Platform
# 13                           Cast/Tow Number
# 14                           Bottom depth
# 15                           probe_type
# 16                           Database origin
# 17                           Originators flag set to use
# 18                                      Instrument
# 19                             scale
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178290 entries, 0 to 178289
# Data columns (total 12 columns):
# #--------------------------------------------------------------------------------    178290 non-null object
# Unnamed: 1                                                                           109764 non-null object
# Unnamed: 2                                                                           168949 non-null object
# Unnamed: 3                                                                           144791 non-null object
# Unnamed: 4                                                                           129158 non-null object
# Unnamed: 5                                                                           101007 non-null object
# Unnamed: 6                                                                           100987 non-null object
# Unnamed: 7                                                                           100792 non-null object
# ...
