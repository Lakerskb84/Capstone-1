# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fish=pd.read_csv('fishing.csv')
print(fish)
# Out:
#      Year         Survey Management Area                Species   CPUE  \
# 0    2017  United States      Bering Sea        Giant grenadier  8.216
# 1    2017  United States      Bering Sea            Pacific cod  2.122
# 2    2017  United States      Bering Sea        Pacific halibut  1.037
# 3    2017  United States      Bering Sea      Rougheye rockfish  0.132
# 4    2017  United States      Bering Sea              Sablefish  3.981
# 5    2017  United States      Bering Sea    Shortraker rockfish  0.441
# 6    2017  United States      Bering Sea  Shortspine thornyhead  0.847
# 7    2016  United States      Bering Sea        Giant grenadier  5.152
# 8    2016  United States      Bering Sea            Pacific cod  1.403
# 9    2016  United States      Bering Sea        Pacific halibut  1.519
# 10   2016  United States      Bering Sea      Rougheye rockfish  0.087
# 11   2016  United States      Bering Sea              Sablefish  2.041
# ...

# %%
fish=fish.groupby(['Year','Species'])['CPUE','RPN','RPW'].mean()
print(fish)
# Out:
#                              CPUE     RPN       RPW
# Year Species
# 2000 Giant grenadier        5.631  126182  564418.0
#      Pacific cod            0.673   15923   56924.0
#      Pacific halibut        2.350   56313       NaN
#      Rougheye rockfish      0.697   14852   22989.0
#      Sablefish              1.463   45225  125699.0
#      Shortraker rockfish    0.375   14094   32430.0
#      Shortspine thornyhead  0.118    2440    3968.0
# 2001 Giant grenadier        3.506   76958  398950.0
#      Pacific cod            2.419   66356  242913.0
#      Pacific halibut        1.372   24645       0.0
#      Rougheye rockfish      0.578   11659   14762.0
#      Sablefish              2.720   84379  256633.0
#      Shortraker rockfish    0.370    8520   17858.0
#      Shortspine thornyhead  0.376    7280    9901.0
# 2002 Giant grenadier        3.031   65162  338243.0
#      Pacific cod            3.270  118681  427086.0
#      Pacific halibut        1.708   28680       NaN
# ...

# %%
fish=fish.reset_index()
print(fish)
# Out:
#      Year                Species   CPUE     RPN       RPW
# 0    2000        Giant grenadier  5.631  126182  564418.0
# 1    2000            Pacific cod  0.673   15923   56924.0
# 2    2000        Pacific halibut  2.350   56313       NaN
# 3    2000      Rougheye rockfish  0.697   14852   22989.0
# 4    2000              Sablefish  1.463   45225  125699.0
# 5    2000    Shortraker rockfish  0.375   14094   32430.0
# 6    2000  Shortspine thornyhead  0.118    2440    3968.0
# 7    2001        Giant grenadier  3.506   76958  398950.0
# 8    2001            Pacific cod  2.419   66356  242913.0
# 9    2001        Pacific halibut  1.372   24645       0.0
# 10   2001      Rougheye rockfish  0.578   11659   14762.0
# 11   2001              Sablefish  2.720   84379  256633.0
# 12   2001    Shortraker rockfish  0.370    8520   17858.0
# 13   2001  Shortspine thornyhead  0.376    7280    9901.0
# 14   2002        Giant grenadier  3.031   65162  338243.0
# ...

# %%
catch=pd.read_csv('Fishing_results.csv')
print(catch)
# Out:
#        Year         Survey  Station  Latitude  Longitude  \
# 0      2017  United States        1    58.778   -177.575
# 1      2017  United States        1    58.778   -177.575
# 2      2017  United States        1    58.778   -177.575
# 3      2017  United States        1    58.778   -177.575
# 4      2017  United States        1    58.778   -177.575
# 5      2017  United States        1    58.778   -177.575
# 6      2017  United States        1    58.778   -177.575
# 7      2017  United States        2    58.620   -176.642
# 8      2017  United States        2    58.620   -176.642
# 9      2017  United States        2    58.620   -176.642
# 10     2017  United States        2    58.620   -176.642
# 11     2017  United States        2    58.620   -176.642
# 12     2017  United States        2    58.620   -176.642
# 13     2017  United States        2    58.620   -176.642
# 14     2017  United States        4    58.497   -175.670
# ...

# %%
catch=catch[(catch.Year >1999) & (catch.Year <2018)]
print(catch)
# Out:
#       Year         Survey  Station  Latitude  Longitude  \
# 0     2017  United States        1    58.778   -177.575
# 1     2017  United States        1    58.778   -177.575
# 2     2017  United States        1    58.778   -177.575
# 3     2017  United States        1    58.778   -177.575
# 4     2017  United States        1    58.778   -177.575
# 5     2017  United States        1    58.778   -177.575
# 6     2017  United States        1    58.778   -177.575
# 7     2017  United States        2    58.620   -176.642
# 8     2017  United States        2    58.620   -176.642
# 9     2017  United States        2    58.620   -176.642
# 10    2017  United States        2    58.620   -176.642
# 11    2017  United States        2    58.620   -176.642
# 12    2017  United States        2    58.620   -176.642
# 13    2017  United States        2    58.620   -176.642
# 14    2017  United States        4    58.497   -175.670
# 15    2017  United States        4    58.497   -175.670
# ...

# %%
catch=catch.groupby(['Year','Species'])['Total Number Caught','Mean Weight (kg)'].mean()
print(catch)
# Out:
#                             Total Number Caught  Mean Weight (kg)
# Year Species
# 2000 Giant grenadier                 972.746032          3.681548
#      Pacific cod                     276.576271          3.085678
#      Pacific halibut                 148.241379               NaN
#      Rougheye rockfish               124.198432          1.457197
#      Sablefish                       877.597701          3.038575
#      Shortraker rockfish             101.535060          1.433783
#      Shortspine thornyhead           139.555556          0.741762
# 2001 Giant grenadier                 840.634921          3.649333
#      Pacific cod                     291.092593          3.222352
#      Pacific halibut                 117.840909               NaN
#      Rougheye rockfish                71.581470          1.523297
#      Sablefish                      1056.539326          3.027539
#      Shortraker rockfish              71.432407          1.566657
# ...

# %%
catch=catch.reset_index()

# %%
m1=pd.merge(fish, catch)
print(m1)
# Out:
#      Year                Species   CPUE     RPN       RPW  \
# 0    2000        Giant grenadier  5.631  126182  564418.0
# 1    2000            Pacific cod  0.673   15923   56924.0
# 2    2000        Pacific halibut  2.350   56313       NaN
# 3    2000      Rougheye rockfish  0.697   14852   22989.0
# 4    2000              Sablefish  1.463   45225  125699.0
# 5    2000    Shortraker rockfish  0.375   14094   32430.0
# 6    2000  Shortspine thornyhead  0.118    2440    3968.0
# 7    2001        Giant grenadier  3.506   76958  398950.0
# 8    2001            Pacific cod  2.419   66356  242913.0
# 9    2001        Pacific halibut  1.372   24645       0.0
# 10   2001      Rougheye rockfish  0.578   11659   14762.0
# 11   2001              Sablefish  2.720   84379  256633.0
# 12   2001    Shortraker rockfish  0.370    8520   17858.0
# 13   2001  Shortspine thornyhead  0.376    7280    9901.0
# 14   2002        Giant grenadier  3.031   65162  338243.0
# ...

# %%
m1=m1.fillna(m1.mean())
print(m1)
# Out:
#      Year                Species   CPUE     RPN           RPW  \
# 0    2000        Giant grenadier  5.631  126182  564418.00000
# 1    2000            Pacific cod  0.673   15923   56924.00000
# 2    2000        Pacific halibut  2.350   56313  149184.42735
# 3    2000      Rougheye rockfish  0.697   14852   22989.00000
# 4    2000              Sablefish  1.463   45225  125699.00000
# 5    2000    Shortraker rockfish  0.375   14094   32430.00000
# 6    2000  Shortspine thornyhead  0.118    2440    3968.00000
# 7    2001        Giant grenadier  3.506   76958  398950.00000
# 8    2001            Pacific cod  2.419   66356  242913.00000
# 9    2001        Pacific halibut  1.372   24645       0.00000
# 10   2001      Rougheye rockfish  0.578   11659   14762.00000
# 11   2001              Sablefish  2.720   84379  256633.00000
# 12   2001    Shortraker rockfish  0.370    8520   17858.00000
# 13   2001  Shortspine thornyhead  0.376    7280    9901.00000
# ...

# %%
carbon=pd.read_csv('Carbon Data.csv')
print(carbon)
# Out:
#      Time      co2 ppm
# 0    1861          286
# 1    1862  286 ppm CO2
# 2    1863  286 ppm CO2
# 3    1864  286 ppm CO2
# 4    1865  286 ppm CO2
# 5    1866  287 ppm CO2
# 6    1867  287 ppm CO2
# 7    1868  287 ppm CO2
# 8    1869  287 ppm CO2
# 9    1870  287 ppm CO2
# 10   1871  287 ppm CO2
# 11   1872  287 ppm CO2
# 12   1873  288 ppm CO2
# 13   1874  288 ppm CO2
# 14   1875  288 ppm CO2
# 15   1876  289 ppm CO2
# 16   1877  289 ppm CO2
# 17   1878  289 ppm CO2
# 18   1879  290 ppm CO2
# 19   1880  290 ppm CO2
# 20   1881  291 ppm CO2
# 21   1882  291 ppm CO2
# 22   1883  292 ppm CO2
# 23   1884  292 ppm CO2
# 24   1885  293 ppm CO2
# 25   1886  293 ppm CO2
# 26   1887  293 ppm CO2
# 27   1888  293 ppm CO2
# 28   1889  294 ppm CO2
# 29   1890  294 ppm CO2
# ..    ...          ...
# 210  2071  685 ppm CO2
# 211  2072  693 ppm CO2
# 212  2073  701 ppm CO2
# 213  2074  709 ppm CO2
# 214  2075  717 ppm CO2
# 215  2076  725 ppm CO2
# 216  2077  733 ppm CO2
# 217  2078  742 ppm CO2
# ...

# %%
carbon=carbon.rename(columns={'Time' : 'Year'})
print(carbon)
# Out:
#      Year      co2 ppm
# 0    1861          286
# 1    1862  286 ppm CO2
# 2    1863  286 ppm CO2
# 3    1864  286 ppm CO2
# 4    1865  286 ppm CO2
# 5    1866  287 ppm CO2
# 6    1867  287 ppm CO2
# 7    1868  287 ppm CO2
# 8    1869  287 ppm CO2
# 9    1870  287 ppm CO2
# 10   1871  287 ppm CO2
# 11   1872  287 ppm CO2
# 12   1873  288 ppm CO2
# 13   1874  288 ppm CO2
# 14   1875  288 ppm CO2
# 15   1876  289 ppm CO2
# 16   1877  289 ppm CO2
# 17   1878  289 ppm CO2
# 18   1879  290 ppm CO2
# 19   1880  290 ppm CO2
# 20   1881  291 ppm CO2
# 21   1882  291 ppm CO2
# 22   1883  292 ppm CO2
# 23   1884  292 ppm CO2
# 24   1885  293 ppm CO2
# 25   1886  293 ppm CO2
# 26   1887  293 ppm CO2
# 27   1888  293 ppm CO2
# 28   1889  294 ppm CO2
# 29   1890  294 ppm CO2
# ..    ...          ...
# 210  2071  685 ppm CO2
# 211  2072  693 ppm CO2
# 212  2073  701 ppm CO2
# 213  2074  709 ppm CO2
# 214  2075  717 ppm CO2
# 215  2076  725 ppm CO2
# 216  2077  733 ppm CO2
# 217  2078  742 ppm CO2
# ...

# %%
carbon=carbon[(carbon.Year >1999) & (carbon.Year <2018)]
print(carbon)
# Out:
#      Year co2 ppm
# 139  2000     369
# 140  2001     370
# 141  2002     373
# 142  2003     375
# 143  2004     377
# 144  2005     379
# 145  2006     381
# 146  2007     383
# 147  2008     385
# 148  2009     387
# 149  2010     389
# 150  2011     392
# 151  2012     394
# 152  2013     396
# 153  2014     399
# 154  2015     402
# 155  2016     404
# 156  2017     407

# %%
carbon['co2 ppm']=carbon['co2 ppm'].apply(lambda x:float(x.split(' ')[0]))
print(carbon)
# Out:
#      Year  co2 ppm
# 139  2000    369.0
# 140  2001    370.0
# 141  2002    373.0
# 142  2003    375.0
# 143  2004    377.0
# 144  2005    379.0
# 145  2006    381.0
# 146  2007    383.0
# 147  2008    385.0
# 148  2009    387.0
# 149  2010    389.0
# 150  2011    392.0
# 151  2012    394.0
# 152  2013    396.0
# 153  2014    399.0
# 154  2015    402.0
# 155  2016    404.0
# 156  2017    407.0

# %%
sea=pd.read_csv('sea_data.csv')
print(sea)
# Out:
#       ID     SIN    String DateAnalyzed  Temp (C)  Method        pH  \
# 0      1  102001       NaN    9/23/2009       NaN       1  7.258863
# 1      2  102002       NaN    9/23/2009       NaN       1  8.053105
# 2      3  102003       NaN    9/23/2009       NaN       1  7.924655
# 3      4  102004       NaN    9/23/2009       NaN       1  7.946720
# 4      5  102005       NaN    9/25/2009       NaN       1  7.891370
# 5      6  102006       NaN    9/25/2009       NaN       1  7.702691
# 6      7  102007       NaN    9/23/2009       NaN       1  7.646043
# 7      8  102008       NaN   10/26/2009       NaN       1  6.840500
# 8      9  102009       NaN   10/26/2009       NaN       1  7.770658
# 9     10  102010       NaN   10/26/2009       NaN       1  7.741867
# 10    11  102011       NaN   10/26/2009       NaN       1  7.668125
# 11    12  102012       NaN    11/6/2009       NaN       1  7.707409
# 12    13  102013       NaN    11/6/2009       NaN       1  7.625372
# ...

# %%
sea['DateAnalyzed']=pd.to_datetime(sea['DateAnalyzed'])
sea['Year']=sea['DateAnalyzed'].dt.year
print(sea)
# Out:
#       ID     SIN    String DateAnalyzed  Temp (C)  Method        pH  \
# 0      1  102001       NaN   2009-09-23       NaN       1  7.258863
# 1      2  102002       NaN   2009-09-23       NaN       1  8.053105
# 2      3  102003       NaN   2009-09-23       NaN       1  7.924655
# 3      4  102004       NaN   2009-09-23       NaN       1  7.946720
# 4      5  102005       NaN   2009-09-25       NaN       1  7.891370
# 5      6  102006       NaN   2009-09-25       NaN       1  7.702691
# 6      7  102007       NaN   2009-09-23       NaN       1  7.646043
# 7      8  102008       NaN   2009-10-26       NaN       1  6.840500
# 8      9  102009       NaN   2009-10-26       NaN       1  7.770658
# 9     10  102010       NaN   2009-10-26       NaN       1  7.741867
# 10    11  102011       NaN   2009-10-26       NaN       1  7.668125
# 11    12  102012       NaN   2009-11-06       NaN       1  7.707409
# 12    13  102013       NaN   2009-11-06       NaN       1  7.625372
# ...

# %%
sea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 9 columns):
# ID              477 non-null int64
# SIN             477 non-null int64
# String          414 non-null object
# DateAnalyzed    477 non-null datetime64[ns]
# Temp (C)        440 non-null float64
# Method          477 non-null int64
# pH              477 non-null float64
# SourceFile      477 non-null object
# Year            477 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 33.6+ KB

# %%
sea=sea.groupby('Year', as_index=False)['Temp (C)','pH'].mean()
print(sea)
# Out:
#    Year   Temp (C)        pH
# 0  2009        NaN  7.607616
# 1  2010  24.694355  7.688334
# 2  2011  24.975758  7.706951
# 3  2012  25.125000  7.717620
# 4  2013  25.125000  7.673176

# %%
sea=sea.fillna(sea.mean())
print(sea)
# Out:
#    Year   Temp (C)        pH
# 0  2009  24.980028  7.607616
# 1  2010  24.694355  7.688334
# 2  2011  24.975758  7.706951
# 3  2012  25.125000  7.717620
# 4  2013  25.125000  7.673176

# %%
m2=pd.merge(m1, carbon)
print(m2)
# Out:
#      Year                Species   CPUE     RPN           RPW  \
# 0    2000        Giant grenadier  5.631  126182  564418.00000
# 1    2000            Pacific cod  0.673   15923   56924.00000
# 2    2000        Pacific halibut  2.350   56313  149184.42735
# 3    2000      Rougheye rockfish  0.697   14852   22989.00000
# 4    2000              Sablefish  1.463   45225  125699.00000
# 5    2000    Shortraker rockfish  0.375   14094   32430.00000
# 6    2000  Shortspine thornyhead  0.118    2440    3968.00000
# 7    2001        Giant grenadier  3.506   76958  398950.00000
# 8    2001            Pacific cod  2.419   66356  242913.00000
# 9    2001        Pacific halibut  1.372   24645       0.00000
# 10   2001      Rougheye rockfish  0.578   11659   14762.00000
# 11   2001              Sablefish  2.720   84379  256633.00000
# 12   2001    Shortraker rockfish  0.370    8520   17858.00000
# 13   2001  Shortspine thornyhead  0.376    7280    9901.00000
# ...

# %%
plt.hist(m3['Total Number Caught'], bins=30)
plt.show()

# %%
plt.hist(m3['CPUE'], bins=30)
plt.show()

# %%
plt.hist(m3['RPN'], bins=30)
plt.show()

# %%
plt.hist(m3['RPW'], bins=30)
plt.show()

# %%
plt.hist(m3['Mean Weight (kg)'], bins=30)
plt.show()

# %%
sns.boxplot('Species', 'Total Number Caught', data=m2)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lmplot('CPUE', 'Total Number Caught', hue='Species', data=m2, truncate=False, size=7)
plt.show()

# %%
sns.boxplot('Species','CPUE', data=m2)
plt.xticks(rotation=90)
plt.show()

# %%
from scipy import stats
from scipy.stats import spearmanr
mean, sigma= np.mean(m2['Total Number Caught']), np.std(m2['Total Number Caught'])
stats.norm.interval(0.95, loc=mean, scale=sigma/ np.sqrt(len(m2['Total Number Caught'])))
# Out:
# (301.00457753093747, 429.73991444328158)

# %%
m2.drop(['Year'],axis=1).corr(method='spearman')
# Out:
#                          CPUE       RPN       RPW  Total Number Caught  \
# CPUE                 1.000000  0.982568  0.843319             0.825402
# RPN                  0.982568  1.000000  0.861968             0.822518
# RPW                  0.843319  0.861968  1.000000             0.763082
# Total Number Caught  0.825402  0.822518  0.763082             1.000000
# Mean Weight (kg)     0.781559  0.785950  0.749298             0.649776
# co2 ppm              0.042248  0.040776 -0.021016             0.001072
#
#                      Mean Weight (kg)   co2 ppm
# CPUE                         0.781559  0.042248
# RPN                          0.785950  0.040776
# RPW                          0.749298 -0.021016
# Total Number Caught          0.649776  0.001072
# Mean Weight (kg)             1.000000 -0.076910
# co2 ppm                     -0.076910  1.000000

# %%
stats.spearmanr(m2['CPUE'], m2['Mean Weight (kg)'])
# Out:
# SpearmanrResult(correlation=0.78155863924235314, pvalue=3.5285183664767918e-27)

# %%
sns.lmplot(x='RPW', y='Total Number Caught', hue='Species', truncate=False, size=7, data=m2)
plt.show()

# %%
stats.spearmanr(m2['RPW'], m2['Total Number Caught'])
# Out:
# SpearmanrResult(correlation=0.76308237381720956, pvalue=2.905907860457883e-25)

# %%
sns.lmplot(x='RPN',y='Total Number Caught', hue='Species', truncate=False, size=7, data=m2)
plt.show()

# %%
stats.spearmanr(m2['RPN'], m2['Total Number Caught'])
# Out:
# SpearmanrResult(correlation=0.82251818522684661, pvalue=3.5218476440236011e-32)

# %%
sns.lmplot(x='CPUE', y='Total Number Caught', hue='Species', truncate=False, size=7, data=m2)
plt.show()

# %%
stats.spearmanr(m2['CPUE'], m2['Total Number Caught'])
# Out:
# SpearmanrResult(correlation=0.82540153912289194, pvalue=1.4022240352361825e-32)

# %%
x=m2['Species']
y=m2['CPUE']
z=m2['Total Number Caught']
plt.xticks(rotation=90)
g=plt.scatter(x, y, c=z, cmap='coolwarm', s=200)
cb=plt.colorbar(g)
cb.set_label('Total Number Caught', rotation=-90, va='bottom')
plt.xlabel('Species')
plt.ylabel('CPUE')
plt.show()

# %%
from scipy.stats import spearmanr
x=m3['CPUE']
y=m3['Total Number Caught']
sns.set(color_codes=True)
a=sns.jointplot(x, y, kind='scatter', stat_func=spearmanr, s=200, color='m', edgecolor='skyblue', linewidth=3)
b=sns.jointplot(x, y, kind='reg', stat_func=spearmanr, color='pink')
plt.show()

# %%
sns.jointplot(x='RPW', y='Mean Weight (kg)', data=m2, kind='scatter', color='blue')
sns.jointplot(x='RPW', y='Mean Weight (kg)', data=m2, kind='reg', color='r')
plt.show()

# %%
sns.jointplot(x='co2 ppm', y='RPW', kind='reg', data=m2, stat_func=spearmanr, color='purple')
plt.show()

# %%
sns.pointplot(x='co2 ppm', y='RPW', hue='Species', data=m2, size=5)
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
sns.pointplot(x='co2 ppm', y='Total Number Caught', hue='Species', data=m2, size=5)
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
sns.pointplot(x='co2 ppm', y='RPN', hue='Species', data=m2, size=5)
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
sns.pointplot(x='co2 ppm', y='CPUE', hue='Species', data=m2, size=5)
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
sns.pointplot(x='co2 ppm', y='Mean Weight (kg)', hue='Species', data=m2, size=5)
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
m3=m2['Species_a']= le.fit_transform(m2['Species'])
m3=m2[['Species_a','CPUE','RPN','RPW','Total Number Caught','Mean Weight (kg)','co2 ppm']]
print(m3)
# Out:
#      Species_a   CPUE     RPN       RPW  Total Number Caught  \
# 0            0  5.631  126182  564418.0           972.746032
# 1            1  0.673   15923   56924.0           276.576271
# 2            2  2.350   56313       0.0           148.241379
# 3            3  0.697   14852   22989.0           124.198432
# 4            4  1.463   45225  125699.0           877.597701
# 5            5  0.375   14094   32430.0           101.535060
# 6            6  0.118    2440    3968.0           139.555556
# 7            0  3.506   76958  398950.0           840.634921
# 8            1  2.419   66356  242913.0           291.092593
# 9            2  1.372   24645       0.0           117.840909
# 10           3  0.578   11659   14762.0            71.581470
# 11           4  2.720   84379  256633.0          1056.539326
# 12           5  0.370    8520   17858.0            71.432407
# 13           6  0.376    7280    9901.0           184.746835
# ...

# %%
m3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 125
# Data columns (total 7 columns):
# Species_a              126 non-null int64
# CPUE                   126 non-null float64
# RPN                    126 non-null int64
# RPW                    126 non-null float64
# Total Number Caught    126 non-null float64
# Mean Weight (kg)       126 non-null float64
# co2 ppm                126 non-null float64
# dtypes: float64(5), int64(2)
# memory usage: 12.9 KB

# %%
from sklearn import preprocessing

X=m3[['CPUE','RPN','RPW','Total Number Caught','Mean Weight (kg)','co2 ppm']]
y=m3['Species_a']

normalized_x= preprocessing.normalize(X)
normalized_x=normalized_x.reshape((normalized_x, (-1,1)))
print(normalized_x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1280-95a83596e9cf> in <module>()
#       5
#       6 normalized_x= preprocessing.normalize(X)
# ----> 7 normalized_x=normalized_x.reshape((normalized_x, (-1,1)))
#       8 print(normalized_x)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
X=normalized_x
y=m3['Species_a']

X_test,X_train,y_test,y_train= train_test_split(x, y, train_size=0.25)

logreg=LogisticRegression(multi_class='multinomial', solver='newton-cg')
logreg.fit(X_train, y_train)
tr=metrics.accuracy_score(y_train, logreg.predict(X_train))
test=metrics.accuracy_score(y_test, logreg.predict(X_test))
print(tr)
print(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1278-b32741db48af> in <module>()
#       8
#       9 logreg=LogisticRegression(multi_class='multinomial', solver='newton-cg')
# ---> 10 logreg.fit(X_train, y_train)
#      11 tr=metrics.accuracy_score(y_train, logreg.predict(X_train))
#      12 test=metrics.accuracy_score(y_test, logreg.predict(X_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1214
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1216                          order="C")
#    1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#
# ...
